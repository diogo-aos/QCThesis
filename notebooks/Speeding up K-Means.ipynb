# %%
# %pylab inline
import numbapro
from numbapro import *
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
class K_Means:
    
    def _init_(self,N=None,D=None):
        self.N=N
        self.D=D
        
    def fit(self,data,K,iters=3,cuda=False):
        
        N,D = data.shape
            
        self.N = N
        self.D = D
        self.K = K
        
        centroids = np.empty((K,D),dtype=data.dtype)
        random_init = np.random.randint(0,N,K)
        self.init_seed = random_init
        
        for k in xrange(K):
            centroids[k] = data[random_init[k]]
        
        self.centroids = centroids
        
        if iters == 0:
            return
        
        for i in xrange(iters):
            dist_mat = self._calc_dists(data,centroids,cuda=cuda)
            assign,grouped_data = self._assign_data(data,dist_mat)
            centroids =  self._recompute_centroids(grouped_data)
            self.centroids = centroids

    def _calc_dists(self,data,centroids,cuda=False):
        if cuda:
            dist_mat = self._cu_calc_dists(data,centroids,gridDim=None,blockDim=None,memManage='manual')
        else:
            dist_mat = self._np_calc_dists(data,centroids)
            
        return dist_mat
            
    def _py_calc_dists(data,centroids):
        N,D = data.shape
        K,cD = centroids.shape

        for n in range(N):
            for k in range(K):
                dist=0
                for d in range(dim):
                    diff = a[n,d]-b[k,d]
                    dist += diff ** 2
                c[n,k]=dist
            
    def _np_calc_dists(self,data,centroids):
        """
        NumPy implementation - much faster than vanilla Python
        """
        N,D = data.shape
        K,cD = centroids.shape

        dist_mat = np.empty((N,K),dtype=data.dtype)    
        
        for k in xrange(K):
            dist = data - centroids[k]
            dist = dist ** 2
            dist_mat[:,k] = dist.sum(axis=1)
            
        return dist_mat
    
    def _cu_calc_dists(self,data,centroids,gridDim=None,blockDim=None,memManage='manual'):
        """
        TODO:
            - deal with gigantic data / distance matrix
            - deal with heavely assymetric distance matrix
                - if the number of blocks on any given dimension of the grid > 2**16,
                divide that dimension by another dimension
                - don't forget to change the index computation in the kernel
        """
        
        
        N,D = data.shape
        K,cD = centroids.shape
        
        if memManage not in ['manual','auto']:
            raise Exception("Invalid value for \'memManage\'.")

            
        if gridDim is None or blockDim is None:
            #dists shape
            

            MAX_THREADS_BLOCK = 28 * 20 # GT520M has 48 CUDA cores
            MAX_GRID_XYZ_DIM = 65535

            if K <= 28:
                blockWidth = K
                blockHeight = np.floor(MAX_THREADS_BLOCK / blockWidth)
                blockHeight = np.int(blockHeight)
            else:
                blockWidth = 28
                blockHeight = 20

            # grid width/height is the number of blocks necessary to fill
            # the columns/rows of the matrix
            gridWidth = np.ceil(np.float(K) / blockWidth)
            gridHeight = np.ceil(np.float(N) / blockHeight)

    
            blockDim = blockWidth, blockHeight
            gridDim = np.int(gridWidth), np.int(gridHeight)
            
        distShape =  N,K
        dist_mat = np.empty(distShape,dtype=data.dtype)
        
        if memManage == 'manual':
            
            dData = cuda.to_device(data)
            dCentroids = cuda.to_device(centroids)
            dDists = numbapro.cuda.device_array_like(dist_mat)
            
            self._cu_dist_kernel[gridDim,blockDim](data,centroids,dDists)        
        
            dDists.copy_to_host(ary=dist_mat)
            numbapro.cuda.synchronize()

        elif memManage == 'auto':
            self.cu_dist[gridDim,blockDim](data,centroids,dist_mat) 
        
        return dist_mat
        
    
    @numbapro.cuda.jit("void(float32[:,:], float32[:,:], float32[:,:])")
    def _cu_dist_kernel(a,b,c):
        k,n = numbapro.cuda.grid(2)
        ch, cw = c.shape # c width and height

        if n >= 10000 or k >= 20:
            return

        dist = 0.0
        for d in range(a.shape[1]):
            diff = a[n,d]-b[k,d]
            dist += diff ** 2
        c[n,k]= dist
    
        
    def _assign_data(self,data,dist_mat):
        
        N,K = dist_mat.shape
        
        assign = np.argmin(dist_mat,axis=1)
        
        gouped_data=[list()] * K
        
        for i in xrange(N):
            # add datum i to its assigned cluster assign[i]
            gouped_data[assign[i]].append(data[i])
        
        for i in xrange(K):
            gouped_data[0] = np.array(gouped_data[0])
        
        return assign,gouped_data
    
    def _recompute_centroids(self,grouped_data):
        
        # change to get dimension from class or search a non-empty cluster
        #dim = grouped_data[0][0].shape[1]
        dim = self.D
        K = len(grouped_data)
        
        centroids = np.empty((K,dim))
        for k in xrange(K):
            centroids[k] = np.mean(grouped_data[k],axis=0)
        
        return centroids

# %%
##generate data
n = 1e6
d = 2
k = 20

total_bytes = (n * d + k * d + n * k) * 4
print 'Memory used by arrays:\t',total_bytes/1024,'\tKBytes'
print '\t\t\t',total_bytes/(1024*1024),'\tMBytes'

print 'Memory used by data:  \t',n * d * 4 / 1024,'\t','KBytes'

data = np.random.random((n,d)).astype(np.float32)
# Out:
# Memory used by arrays:	85937.65625 	KBytes
# 			83.9234924316 	MBytes
# Memory used by data:  	7812.5 	KBytes

# %%
from timeit import default_timer as timer

# %%
times=dict()

# %%
start = timer()
grouperCUDA = K_Means()
grouperCUDA.fit(data,k,iters=3,cuda=True)
times['cuda'] = timer() - start

# %%
#%debug
start = timer()
grouperNP = K_Means()
grouperNP.fit(data,k,cuda=False)
times['numpy'] = timer() - start

# %%
print 'Times'
print 'CUDA ','\t',times['cuda']
print 'NumPy','\t',times['numpy']
# Out:
# Times
# CUDA  	29.3555300236
# NumPy 	32.5373690128

# %%
import cProfile
#from line_profiler import LineProfiler
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-16-a0b61c615a14> in <module>()
# ----> 1 from line_profiler import LineProfiler
#
# ImportError: No module named line_profiler

# %%
#profile = LineProfiler(grouperCUDA.fit(data,k,iters=3,cuda=True))
#profile.print_stats()
cProfile.run("grouperCUDA.fit(data,k,iters=3,cuda=True)")
# Out:
#          3004214 function calls (3004151 primitive calls) in 31.261 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    2.853    0.951    4.567    1.522 <ipython-input-2-892962712a65>:146(_assign_data)
#         3    0.001    0.000   25.282    8.427 <ipython-input-2-892962712a65>:163(_recompute_centroids)
#         3    0.000    0.000    0.957    0.319 <ipython-input-2-892962712a65>:33(_calc_dists)
#         3    0.000    0.000    0.956    0.319 <ipython-input-2-892962712a65>:69(_cu_calc_dists)
#         1    0.287    0.287   31.127   31.127 <ipython-input-2-892962712a65>:7(fit)
#         1    0.134    0.134   31.261   31.261 <string>:1(<module>)
#        15    0.000    0.000    0.000    0.000 <string>:8(__new__)
#        30    0.000    0.000    0.074    0.002 _methods.py:34(_prod)
#        60    0.001    0.000    0.001    0.000 _methods.py:43(_count_reduce_items)
#        60    0.033    0.001   25.279    0.421 _methods.py:53(_mean)
#         3    0.000    0.000    0.000    0.000 api.py:116(synchronize)
#         3    0.000    0.000    0.000    0.000 api.py:121(_prepare_shape_strides_dtype)
#         3    0.000    0.000    0.002    0.001 api.py:150(device_array_like)
#         6    0.000    0.000    0.395    0.066 api.py:23(to_device)
#         3    0.000    0.000    0.002    0.001 api.py:63(device_array)
#        30    0.036    0.001    0.036    0.001 arrayobj.py:46(make_array_ctype)
#        30    0.000    0.000    0.000    0.000 arrayobj.py:61(c_array)
#         3    0.000    0.000    0.000    0.000 compiler.py:172(copy)
#         3    0.000    0.000    0.000    0.000 compiler.py:175(configure)
#         3    0.000    0.000    0.000    0.000 compiler.py:201(__getitem__)
#         3    0.000    0.000    0.000    0.000 compiler.py:250(get)
#         3    0.000    0.000    0.177    0.059 compiler.py:301(__call__)
#         3    0.000    0.000    0.176    0.059 compiler.py:326(_kernel_call)
#         9    0.000    0.000    0.104    0.012 compiler.py:377(_prepare_args)
#         6    0.000    0.000    0.072    0.012 compiler.py:381(<lambda>)
#        15    0.000    0.000    0.000    0.000 contextlib.py:12(__init__)
#        15    0.000    0.000    0.000    0.000 contextlib.py:15(__enter__)
#        15    0.000    0.000    0.000    0.000 contextlib.py:21(__exit__)
#        15    0.000    0.000    0.000    0.000 contextlib.py:82(helper)
#         6    0.000    0.000    0.000    0.000 copy.py:306(_reconstruct)
#         6    0.000    0.000    0.000    0.000 copy.py:66(copy)
#         6    0.000    0.000    0.000    0.000 copy_reg.py:92(__newobj__)
#        15    0.000    0.000    0.000    0.000 devicearray.py:123(__del__)
#        21    0.000    0.000    0.000    0.000 devicearray.py:129(_default_stream)
#        21    0.000    0.000    0.000    0.000 devicearray.py:141(device_ctypes_pointer)
#        12    0.000    0.000    0.017    0.001 devicearray.py:151(copy_to_device)
#         9    0.000    0.000    0.373    0.041 devicearray.py:168(copy_to_host)
#         9    0.000    0.000    0.000    0.000 devicearray.py:232(as_cuda_arg)
#        12    0.000    0.000    0.443    0.037 devicearray.py:332(from_array_like)
#         6    0.039    0.007    0.039    0.007 devicearray.py:347(sentry_contiguous)
#         9    0.000    0.000    0.104    0.012 devicearray.py:353(auto_device)
#        15    0.014    0.001    0.445    0.030 devicearray.py:56(__init__)
#        45    0.000    0.000    0.081    0.002 devices.py:108(current_context)
#        45    0.000    0.000    0.082    0.002 devices.py:183(get_or_create_context)
#        45    0.000    0.000    0.082    0.002 devices.py:224(get_context)
#         9    0.000    0.000    0.478    0.053 devices.py:236(_require_cuda_context)
#         3    0.000    0.000    0.000    0.000 driver.py:1018(configure)
#         3    0.000    0.000    0.000    0.000 driver.py:1035(__call__)
#         3    0.000    0.000    0.000    0.000 driver.py:1070(launch_kernel)
#        36    0.000    0.000    0.000    0.000 driver.py:1247(host_pointer)
#        12    0.000    0.000    0.000    0.000 driver.py:1258(host_memory_extents)
#        15    0.029    0.002    0.029    0.002 driver.py:1263(memory_size_from_info)
#        12    0.000    0.000    0.000    0.000 driver.py:1273(host_memory_size)
#        51    0.000    0.000    0.001    0.000 driver.py:1280(device_pointer)
#        60    0.000    0.000    0.001    0.000 driver.py:1285(device_ctypes_pointer)
#        90    0.000    0.000    0.000    0.000 driver.py:1293(is_device_memory)
#        60    0.000    0.000    0.000    0.000 driver.py:1304(require_device_memory)
#        15    0.000    0.000    0.000    0.000 driver.py:1311(device_memory_depends)
#        27    0.000    0.000    0.113    0.004 driver.py:1321(host_to_device)
#         9    0.000    0.000    0.373    0.041 driver.py:1339(device_to_host)
#       147    0.704    0.005    0.704    0.005 driver.py:212(safe_cuda_api_call)
#       147    0.000    0.000    0.000    0.000 driver.py:241(_check_error)
#        45    0.000    0.000    0.081    0.002 driver.py:270(get_context)
#        15    0.000    0.000    0.000    0.000 driver.py:291(add_trash)
#        15    0.000    0.000    0.071    0.005 driver.py:294(process)
#        15    0.052    0.003    0.191    0.013 driver.py:498(memalloc)
#         3    0.000    0.000    0.000    0.000 driver.py:614(synchronize)
#        15    0.000    0.000    0.000    0.000 driver.py:664(_make_mem_finalizer)
#        15    0.000    0.000    0.000    0.000 driver.py:665(mem_finalize)
#        15    0.000    0.000    0.000    0.000 driver.py:669(core)
#        15    0.000    0.000    0.071    0.005 driver.py:670(cleanup)
#        15    0.000    0.000    0.000    0.000 driver.py:728(__init__)
#        15    0.000    0.000    0.000    0.000 driver.py:739(__del__)
#        15    0.000    0.000    0.000    0.000 driver.py:746(own)
#        15    0.000    0.000    0.000    0.000 driver.py:749(free)
#        60    0.000    0.000    0.000    0.000 driver.py:778(device_ctypes_pointer)
#        15    0.000    0.000    0.000    0.000 driver.py:838(__init__)
#        15    0.000    0.000    0.000    0.000 driver.py:847(__del__)
#       123    0.000    0.000    0.000    0.000 driver.py:858(__getattr__)
#        15    0.000    0.000    0.000    0.000 driver.py:911(query)
#        15    0.000    0.000    0.000    0.000 driver.py:925(record)
#        30    0.000    0.000    0.000    0.000 dummyarray.py:104(is_contiguous)
#        30    0.000    0.000    0.000    0.000 dummyarray.py:108(compute_index)
#        90    0.000    0.000    0.000    0.000 dummyarray.py:109(<genexpr>)
#        15    0.000    0.000    0.075    0.005 dummyarray.py:148(from_desc)
#        15    0.000    0.000    0.074    0.005 dummyarray.py:157(__init__)
#        45    0.000    0.000    0.000    0.000 dummyarray.py:160(<genexpr>)
#        45    0.000    0.000    0.000    0.000 dummyarray.py:161(<genexpr>)
#        15    0.000    0.000    0.000    0.000 dummyarray.py:167(_compute_layout)
#        15    0.000    0.000    0.000    0.000 dummyarray.py:172(is_contig)
#        15    0.000    0.000    0.000    0.000 dummyarray.py:184(_compute_extent)
#        30    0.000    0.000    0.000    0.000 dummyarray.py:27(__init__)
#        60    0.000    0.000    0.000    0.000 dummyarray.py:80(get_offset)
#        30    0.000    0.000    0.074    0.002 fromnumeric.py:2259(prod)
#        60    0.001    0.000   25.280    0.421 fromnumeric.py:2651(mean)
#         3    0.000    0.000    0.129    0.043 fromnumeric.py:946(argmin)
#        15    0.001    0.000    0.135    0.009 ndarray.py:130(ndarray_populate_head)
#        15    0.000    0.000    0.000    0.000 ndarray.py:42(__new__)
#        30    0.000    0.000    0.001    0.000 ndarray.py:69(get_stage)
#        15    0.000    0.000    0.001    0.000 ndarray.py:80(allocate)
#        15    0.000    0.000    0.000    0.000 ndarray.py:91(free)
#        15    0.000    0.000    0.097    0.006 ndarray.py:96(write)
#        60    0.000    0.000   22.507    0.375 numeric.py:464(asanyarray)
#        15    0.000    0.000    0.071    0.005 service.py:18(service)
#        90    0.000    0.000    0.000    0.000 threadlocal.py:13(stack)
#        45    0.000    0.000    0.000    0.000 threadlocal.py:29(top)
#        45    0.000    0.000    0.000    0.000 threadlocal.py:33(is_empty)
#        45    0.000    0.000    0.000    0.000 threadlocal.py:37(__bool__)
#        45    0.000    0.000    0.000    0.000 threadlocal.py:40(__nonzero__)
#        15    0.000    0.000    0.000    0.000 utils.py:142(__setitem__)
#         9    0.000    0.000    0.000    0.000 {_ctypes.addressof}
#        60    0.000    0.000    0.000    0.000 {_ctypes.byref}
#        30    0.000    0.000    0.000    0.000 {_ctypes.sizeof}
#        30    0.000    0.000    0.000    0.000 {_weakref.proxy}
#        21    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x7f668bf82d00}
#   240/177    0.000    0.000    0.001    0.000 {getattr}
#         6    0.000    0.000    0.000    0.000 {hasattr}
#         6    0.000    0.000    0.000    0.000 {id}
#       225    0.001    0.000    0.001    0.000 {isinstance}
#        60    0.000    0.000    0.000    0.000 {issubclass}
#       144    0.000    0.000    0.000    0.000 {len}
#         6    0.000    0.000    0.000    0.000 {method '__reduce_ex__' of 'object' objects}
#        15    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        30    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#   3000066    0.294    0.000    0.294    0.000 {method 'append' of 'list' objects}
#         3    0.129    0.043    0.129    0.043 {method 'argmin' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        15    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#        15    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        30    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        15    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#        30    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         1    0.035    0.035    0.035    0.035 {method 'randint' of 'mtrand.RandomState' objects}
#        90    2.811    0.031    2.811    0.031 {method 'reduce' of 'numpy.ufunc' objects}
#         6    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        12    0.000    0.000    0.000    0.000 {min}
#        30    0.000    0.000    0.071    0.002 {next}
#        36    0.000    0.000    0.000    0.000 {numba.mviewbuf.memoryview_get_buffer}
#        15    0.000    0.000    0.000    0.000 {numba.mviewbuf.memoryview_get_extents_info}
#        12    0.000    0.000    0.000    0.000 {numba.mviewbuf.memoryview_get_extents}
#       120   23.798    0.198   23.798    0.198 {numpy.core.multiarray.array}
#         7    0.000    0.000    0.000    0.000 {numpy.core.multiarray.empty}
#        30    0.000    0.000    0.000    0.000 {sum}
#        48    0.000    0.000    0.000    0.000 {zip}

# %%
cProfile.run("grouperCUDA.fit(data,k,iters=3,cuda=False)")
# Out:
#          3000812 function calls in 34.920 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         3    2.901    0.967    4.678    1.559 <ipython-input-2-892962712a65>:146(_assign_data)
#         3    0.001    0.000   25.740    8.580 <ipython-input-2-892962712a65>:163(_recompute_centroids)
#         3    0.000    0.000    4.101    1.367 <ipython-input-2-892962712a65>:33(_calc_dists)
#         3    2.409    0.803    4.101    1.367 <ipython-input-2-892962712a65>:53(_np_calc_dists)
#         1    0.262    0.262   34.781   34.781 <ipython-input-2-892962712a65>:7(fit)
#         1    0.139    0.139   34.920   34.920 <string>:1(<module>)
#        60    0.000    0.000    1.678    0.028 _methods.py:31(_sum)
#        60    0.001    0.000    0.001    0.000 _methods.py:43(_count_reduce_items)
#        60    0.005    0.000   25.737    0.429 _methods.py:53(_mean)
#        60    0.001    0.000   25.738    0.429 fromnumeric.py:2651(mean)
#         3    0.000    0.000    0.155    0.052 fromnumeric.py:946(argmin)
#        60    0.000    0.000   22.940    0.382 numeric.py:464(asanyarray)
#       120    0.001    0.000    0.001    0.000 {isinstance}
#        60    0.000    0.000    0.000    0.000 {issubclass}
#         3    0.000    0.000    0.000    0.000 {len}
#   3000000    0.288    0.000    0.288    0.000 {method 'append' of 'list' objects}
#         3    0.155    0.052    0.155    0.052 {method 'argmin' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'randint' of 'mtrand.RandomState' objects}
#       120    4.469    0.037    4.469    0.037 {method 'reduce' of 'numpy.ufunc' objects}
#        60    0.014    0.000    1.692    0.028 {method 'sum' of 'numpy.ndarray' objects}
#       120   24.274    0.202   24.274    0.202 {numpy.core.multiarray.array}
#         7    0.000    0.000    0.000    0.000 {numpy.core.multiarray.empty}

# %%
print 'Speedup:','\t\t', 1.367/0.319
print 'Centroids portion','\t',25.2/31
# Out:
# Speedup: 		4.28526645768
# Centroids portion 	0.812903225806

# %% [markdown]
# Profiling both runs (CUDA and NumPy) we see that we have a speedup, but it's very small. In fact, the speedup of the optimized portions of the code is around 4 but the rest is so slow that it makes very little impact. What's taking the most time is the centroid recalculation, taking around 80% of the total time. This is the obvious next step for optimization.

# %%
print grouperCUDA.centroids
print grouperCUDA.init_seed
print grouperNP.centroids
# Out:
# [[ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]]
# [529814 854332 998308 625841 600956 323058 439920 178831 703431 619616
#   34449 113101 766481 993301 700309 204698  38339 280205 429147 298395]
# [[ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]
#  [ 0.4996427   0.50006068]]
